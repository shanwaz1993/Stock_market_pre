# %%
import numpy as np
import pandas as pd

df_sales= pd.read_csv('/home/shan/noorprojdata/productsale.csv')
#print(df_sales.info())
#df_sales.head()

#df_sales['Price']=pd.to_numeric(df_sales['Price'],errors='coercer')
print(df_sales.info())
df_sales.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
# Week         4 non-null object
# Product      4 non-null object
# Salecount    4 non-null int64
# dtypes: int64(1), object(2)
# memory usage: 168.0+ bytes
# None
#   Week   Product  Salecount
# 0   W1  Product1        200
# 1   W2  Product1        400
# 2   W3  Product1        300
# 3   W4  Product1        500

# %%
ax = df_sales['Week'].rename(columns={"Product": "Product Cate"}).plot(title='Product and Price')
ax.set_xlabel("Dates")
ax.set_ylabel("product")
fig = df_sales['Salecount'].rename(columns={"Salecount": "count"}).plot(ax = ax).get_figure()
fig.savefig("/home/shan/noorprojdata/sale_graph1.png")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-d47a48dc8184> in <module>()
#       1
# ----> 2 ax = df_sales['Week'].rename(columns={"Product": "Product Cate"}).plot(title='Product and Price')
#       3 ax.set_xlabel("Dates")
#       4 ax.set_ylabel("product")
#       5 fig = df_sales['Salecount'].rename(columns={"Salecount": "count"}).plot(ax = ax).get_figure()
#
# /home/shan/anaconda3/lib/python2.7/site-packages/pandas/plotting/_core.pyc in __call__(self, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    2740                            colormap=colormap, table=table, yerr=yerr,
#    2741                            xerr=xerr, label=label, secondary_y=secondary_y,
# -> 2742                            **kwds)
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')
data = np.random.randn(1000)
#plt.hist(data)
plt.hist(df_sales['Week'],bin=4,density=True,alpha=0.5,histtype='stepfilled',color='b',edgecolor='none') #other options
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-c5cfcd8cfb7e> in <module>()
#       4 data = np.random.randn(1000)
#       5 #plt.hist(data)
# ----> 6 plt.hist(df_sales['Week'],bin=4,density=True,alpha=0.5,histtype='stepfilled',color='b',edgecolor='none') #other options
#       7 plt.show()
#
# /home/shan/anaconda3/lib/python2.7/site-packages/matplotlib/pyplot.pyc in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, normed, hold, data, **kwargs)
#    3135                       histtype=histtype, align=align, orientation=orientation,
#    3136                       rwidth=rwidth, log=log, color=color, label=label,
# -> 3137                       stacked=stacked, normed=normed, data=data, **kwargs)
#    3138     finally:
#    3139         ax._hold = washold
#
# ...

# %%
import matplotlib as mlt
import matplotlib.pyplot as plt

import numpy as np

df_product1= pd.read_csv('/home/shan/noorprojdata/productsale.csv')
df_product2= pd.read_csv('/home/shan/noorprojdata/productsale2.csv')
df_product3= pd.read_csv('/home/shan/noorprojdata/productsale3.csv')

df_product1
# Out:
#   Week   Product  Salecount  Profit
# 0   W1  Product1        200    8000
# 1   W2  Product1        400   15000
# 2   W3  Product1        300   12000
# 3   W4  Product1        500   10000

# %%
fig=plt.figure()

plt.plot(df_product1['Week'],df_product1['Salecount'],'-')
plt.plot(df_product2['Week'],df_product2['Salecount'],'-')
plt.plot(df_product3['Week'],df_product3['Salecount'],'-')
#lbl=plt.plot(,y)
plt.legend(['Product1', 'Product2','Product1',],loc='Lower right')
# Out:
# /home/shan/anaconda3/lib/python2.7/site-packages/matplotlib/legend.py:640: UserWarning: Unrecognized location "Lower right". Falling back on "best"; valid locations are
# 	right
# 	center left
# 	upper right
# 	lower right
# 	best
# 	center
# 	lower left
# 	center right
# 	upper left
# 	upper center
# 	lower center
#
#   % (loc, '\n\t'.join(self.codes)))

# %%
plt.plot(df_product1['Week'],df_product1['Profit'],'-')
plt.plot(df_product2['Week'],df_product2['Profit'],'-')
plt.plot(df_product3['Week'],df_product3['Profit'],'-')
#lbl=plt.plot(,y)
plt.legend(['Product1', 'Product2','Product1',],loc='Lower right')

# %%
plt.plot(df_product1['Profit'],df_product1['Salecount'],'-')
plt.plot(df_product2['Profit'],df_product2['Salecount'],'-')
plt.plot(df_product3['Profit'],df_product3['Salecount'],'-')
#lbl=plt.plot(,y)
plt.legend(['Product1', 'Product2','Product1',],loc='Lower right')
